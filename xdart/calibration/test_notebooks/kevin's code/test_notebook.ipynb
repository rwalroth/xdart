# %%
# %matplotlib notebook

import sys, os, glob, imp, fnmatch, re
from copy import deepcopy

import matplotlib.pyplot as plt

import numpy as np
import scipy

from collections import OrderedDict

from ipywidgets import *
from IPython.display import display, Image

from lmfit import Model, Parameters
from lmfit.models import LinearModel, GaussianModel, PseudoVoigtModel

from mpl_toolkits.axes_grid1 import make_axes_locatable

import pyFAI
from pyFAI.multi_geometry import MultiGeometry
from silx.io.specfile import SpecFile

from joblib import Parallel, delayed
import multiprocessing as mp

sys.path.append('C:\\Users\\Public\\repos\\xdart')
from xdart.utils import get_motor_val
from xdart.utils import get_from_pdi, query_yes_no, read_image_file, smooth_img, get_fit, fit_images_2D
from xdart.pySSRL_bServer.bServer_funcs import specCommand, wait_until_SPECfinished, get_console_output

import time
from pathlib import Path

# %%
specCommand("print PD_SAVEPATH ' ' DATAFILE  ' ' SCAN_N", print_console=False)
# Out:
# Executed

# %%
out = get_console_output(idx=1)[0]
out
# Out:
# '~/data/Feb2020/images/ test 2'

# %%
pd_savepath, filename, scan_n = out.split(' ')

# %%
specCommand(f'pd savepath {pd_savepath}; newfile_f("{filename}", {scan_n})')#, print_console=False)
# Out:
# Executed

# %%
specCommand('p "saved settings restored"')
# Out:
# Executed

# %%
path = 'P:\\bl2-1\\Feb2020'

scan4 = 'Scan4_Integrate_1D_Live.xye'
scan5 = 'Scan4_Integrate_1D_batch.xye'

int_1d_scan4_live = np.loadtxt(os.path.join(path, scan4))
int_1d_scan5_live = np.loadtxt(os.path.join(path, scan5))

# %%
plt.figure()

x1, y1 = int_1d_scan4_live[:,0], int_1d_scan4_live[:,1]
x2, y2 = int_1d_scan5_live[:,0], int_1d_scan5_live[:,1]

plt.plot(x1, y1)
plt.plot(x2, y2)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
from xdart.pySSRL_bServer.watcher import Watcher

# %%
watcher = Watcher()

#watcher.watchPaths = ['Z:\\', 'P:\\bl2-1\\Feb2020\\images']
watcher.watchPaths = ['P:\\bl2-1\\Feb2020\\images']
watcher.filetypes = ['pdi']
watcher.verbose = True

# %%
watcher.run()
# Out:
# pdi - Added: ['P:\\bl2-1\\Feb2020\\images\\b_stone_LaB6_capillary_beamstop_2_scan7_0000.raw.pdi']
# pdi - Added: ['P:\\bl2-1\\Feb2020\\images\\b_stone_LaB6_capillary_beamstop_2_scan7_0001.raw.pdi']
# pdi - Added: ['P:\\bl2-1\\Feb2020\\images\\b_stone_LaB6_capillary_beamstop_2_scan7_0002.raw.pdi']
# pdi - Added: ['P:\\bl2-1\\Feb2020\\images\\b_stone_LaB6_capillary_beamstop_2_scan7_0003.raw.pdi']
# pdi - Added: ['P:\\bl2-1\\Feb2020\\images\\b_stone_LaB6_capillary_beamstop_2_scan7_0004.raw.pdi']
# pdi - Added: ['P:\\bl2-1\\Feb2020\\images\\b_stone_LaB6_capillary_beamstop_2_scan7_0005.raw.pdi']
# pdi - Added: ['P:\\bl2-1\\Feb2020\\images\\b_stone_LaB6_capillary_beamstop_2_scan7_0006.raw.pdi']
# pdi - Added: ['P:\\bl2-1\\Feb2020\\images\\b_stone_LaB6_capillary_beamstop_2_scan7_0007.raw.pdi']
# pdi - Added: ['P:\\bl2-1\\Feb2020\\images\\b_stone_LaB6_capillary_beamstop_2_scan7_0008.raw.pdi']
# pdi - Added: ['P:\\bl2-1\\Feb2020\\images\\b_stone_LaB6_capillary_beamstop_2_scan7_0009.raw.pdi']
# pdi - Added: ['P:\\bl2-1\\Feb2020\\images\\b_stone_LaB6_capillary_beamstop_2_scan7_0010.raw.pdi']
# pdi - Added: ['P:\\bl2-1\\Feb2020\\images\\b_stone_LaB6_capillary_beamstop_2_scan7_0011.raw.pdi']
# pdi - Added: ['P:\\bl2-1\\Feb2020\\images\\b_stone_LaB6_capillary_beamstop_2_scan7_0012.raw.pdi']
# pdi - Added: ['P:\\bl2-1\\Feb2020\\images\\b_stone_LaB6_capillary_beamstop_2_scan7_0013.raw.pdi']
# pdi - Added: ['P:\\bl2-1\\Feb2020\\images\\b_stone_LaB6_capillary_beamstop_2_scan7_0014.raw.pdi']
# pdi - Added: ['P:\\bl2-1\\Feb2020\\images\\b_stone_LaB6_capillary_beamstop_2_scan7_0015.raw.pdi']
# pdi - Added: ['P:\\bl2-1\\Feb2020\\images\\b_stone_LaB6_capillary_beamstop_2_scan7_0016.raw.pdi']
# pdi - Added: ['P:\\bl2-1\\Feb2020\\images\\b_stone_LaB6_capillary_beamstop_2_scan7_0017.raw.pdi']
# pdi - Added: ['P:\\bl2-1\\Feb2020\\images\\b_stone_LaB6_capillary_beamstop_2_scan7_0018.raw.pdi']
# pdi - Added: ['P:\\bl2-1\\Feb2020\\images\\b_stone_LaB6_capillary_beamstop_2_scan7_0019.raw.pdi']
# pdi - Added: ['P:\\bl2-1\\Feb2020\\images\\b_stone_LaB6_capillary_beamstop_2_scan7_0020.raw.pdi']
# pdi - Added: ['P:\\bl2-1\\Feb2020\\images\\b_stone_LaB6_capillary_beamstop_2_scan7_0021.raw.pdi']
# pdi - Added: ['P:\\bl2-1\\Feb2020\\images\\b_stone_LaB6_capillary_beamstop_2_scan7_0022.raw.pdi']
# pdi - Added: ['P:\\bl2-1\\Feb2020\\images\\b_stone_LaB6_capillary_beamstop_2_scan7_0023.raw.pdi']
# pdi - Added: ['P:\\bl2-1\\Feb2020\\images\\b_stone_LaB6_capillary_beamstop_2_scan7_0024.raw.pdi']
# pdi - Added: ['P:\\bl2-1\\Feb2020\\images\\b_stone_LaB6_capillary_beamstop_2_scan7_0025.raw.pdi']
# pdi - Added: ['P:\\bl2-1\\Feb2020\\images\\b_stone_LaB6_capillary_beamstop_2_scan7_0026.raw.pdi']
# pdi - Added: ['P:\\bl2-1\\Feb2020\\images\\b_stone_LaB6_capillary_beamstop_2_scan7_0027.raw.pdi']
# pdi - Added: ['P:\\bl2-1\\Feb2020\\images\\b_stone_LaB6_capillary_beamstop_2_scan7_0028.raw.pdi']
# pdi - Added: ['P:\\bl2-1\\Feb2020\\images\\b_stone_LaB6_capillary_beamstop_2_scan7_0029.raw.pdi']
# pdi - Added: ['P:\\bl2-1\\Feb2020\\images\\b_stone_LaB6_capillary_beamstop_2_scan7_0030.raw.pdi']
# pdi - Added: ['P:\\bl2-1\\Feb2020\\images\\b_stone_LaB6_capillary_beamstop_2_scan7_0031.raw.pdi']
# pdi - Added: ['P:\\bl2-1\\Feb2020\\images\\b_stone_LaB6_capillary_beamstop_2_scan7_0032.raw.pdi']
# pdi - Added: ['P:\\bl2-1\\Feb2020\\images\\b_stone_LaB6_capillary_beamstop_2_scan7_0033.raw.pdi']
# pdi - Added: ['P:\\bl2-1\\Feb2020\\images\\b_stone_LaB6_capillary_beamstop_2_scan7_0034.raw.pdi']
# pdi - Added: ['P:\\bl2-1\\Feb2020\\images\\b_stone_LaB6_capillary_beamstop_2_scan7_0035.raw.pdi']
# pdi - Added: ['P:\\bl2-1\\Feb2020\\images\\b_stone_LaB6_capillary_beamstop_2_scan7_0036.raw.pdi']
# pdi - Added: ['P:\\bl2-1\\Feb2020\\images\\b_stone_LaB6_capillary_beamstop_2_scan7_0037.raw.pdi']
# pdi - Added: ['P:\\bl2-1\\Feb2020\\images\\b_stone_LaB6_capillary_beamstop_2_scan7_0038.raw.pdi']
# pdi - Added: ['P:\\bl2-1\\Feb2020\\images\\b_stone_LaB6_capillary_beamstop_2_scan7_0039.raw.pdi']
# pdi - Added: ['P:\\bl2-1\\Feb2020\\images\\b_stone_LaB6_capillary_beamstop_2_scan7_0040.raw.pdi']
# pdi - Added: ['P:\\bl2-1\\Feb2020\\images\\b_stone_LaB6_capillary_beamstop_2_scan7_0041.raw.pdi']
# pdi - Added: ['P:\\bl2-1\\Feb2020\\images\\b_stone_LaB6_capillary_beamstop_2_scan7_0042.raw.pdi']
# pdi - Added: ['P:\\bl2-1\\Feb2020\\images\\b_stone_LaB6_capillary_beamstop_2_scan7_0043.raw.pdi']
# pdi - Added: ['P:\\bl2-1\\Feb2020\\images\\b_stone_LaB6_capillary_beamstop_2_scan7_0044.raw.pdi']
# pdi - Added: ['P:\\bl2-1\\Feb2020\\images\\b_stone_LaB6_capillary_beamstop_2_scan7_0045.raw.pdi']
# pdi - Added: ['P:\\bl2-1\\Feb2020\\images\\b_stone_LaB6_capillary_beamstop_2_scan7_0046.raw.pdi']
# pdi - Added: ['P:\\bl2-1\\Feb2020\\images\\b_stone_LaB6_capillary_beamstop_2_scan7_0047.raw.pdi']
# pdi - Added: ['P:\\bl2-1\\Feb2020\\images\\b_stone_LaB6_capillary_beamstop_2_scan7_0048.raw.pdi']
# pdi - Added: ['P:\\bl2-1\\Feb2020\\images\\b_stone_LaB6_capillary_beamstop_2_scan7_0049.raw.pdi']
# pdi - Added: ['P:\\bl2-1\\Feb2020\\images\\b_stone_LaB6_capillary_beamstop_2_scan7_0050.raw.pdi']
# pdi - Added: ['P:\\bl2-1\\Feb2020\\images\\b_stone_LaB6_capillary_beamstop_2_scan7_0051.raw.pdi']
# pdi - Added: ['P:\\bl2-1\\Feb2020\\images\\b_stone_LaB6_capillary_beamstop_2_scan7_0052.raw.pdi']
# pdi - Added: ['P:\\bl2-1\\Feb2020\\images\\b_stone_LaB6_capillary_beamstop_2_scan7_0053.raw.pdi']
# pdi - Added: ['P:\\bl2-1\\Feb2020\\images\\b_stone_LaB6_capillary_beamstop_2_scan7_0054.raw.pdi']
# pdi - Added: ['P:\\bl2-1\\Feb2020\\images\\b_stone_LaB6_capillary_beamstop_2_scan7_0055.raw.pdi']
# pdi - Added: ['P:\\bl2-1\\Feb2020\\images\\b_stone_LaB6_capillary_beamstop_2_scan7_0056.raw.pdi']
# pdi - Added: ['P:\\bl2-1\\Feb2020\\images\\b_stone_LaB6_capillary_beamstop_2_scan7_0057.raw.pdi']
# pdi - Added: ['P:\\bl2-1\\Feb2020\\images\\b_stone_LaB6_capillary_beamstop_2_scan7_0058.raw.pdi']
# pdi - Added: ['P:\\bl2-1\\Feb2020\\images\\b_stone_LaB6_capillary_beamstop_2_scan7_0059.raw.pdi']
# pdi - Added: ['P:\\bl2-1\\Feb2020\\images\\b_stone_LaB6_capillary_beamstop_2_scan7_0060.raw.pdi']
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-15-13ee799c6e03> in <module>
# ----> 1 watcher.run()
#
# C:\Users\Public\repos\xdart\xdart\pySSRL_bServer\watcher.py in run(self)
#      54                     before[filetype] = after[filetype]
#      55
# ---> 56             time.sleep (self.pollingPeriod)
#
# KeyboardInterrupt:

# %%
os.scandir('Z:\\')

# %%
os.scandir?

# %%
files = [f.stat().st_atime for f in os.scandir('Z:\\')]

# %%
plt.figure()
plt.plot(files)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
f = files[0]

# %%
fstat
# Out:
# os.stat_result(st_mode=33206, st_ino=0, st_dev=0, st_nlink=0, st_uid=0, st_gid=0, st_size=379860, st_atime=1581865940, st_mtime=1581865938, st_ctime=1581865938)

# %%
fstat = f.stat()
fstat.st_atime
# Out:
# 1581865940.7327726

# %%
files = os.listdir('Z:\\')

# %%
import glob
files = glob.glob('Z:\\*.raw')

# %%
os.walk?

# %%
import pathlib

path = pathlib.Path('Z:\\')
files = [f for f in path.glob('*.raw')]

# %%
os.path.dirname('Z:\\abc.png')
# Out:
# 'Z:\\'
